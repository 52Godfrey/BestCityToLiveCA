# %%
import pandas as pd
import os

# %%
pwd
# Out:
# 'C:\\Users\\mgeam\\BestCityToLiveCA\\Resources\\CrimeData'

# %%
CrimeData = "C:\\Users\\mgeam\\BestCityToLiveCA\\Resources\\CrimeData\\CountyCrime.csv"

# %%
open(CrimeData)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\mgeam\\BestCityToLiveCA\\Resources\\CrimeData\\CountyCrime.csv' mode='r' encoding='cp1252'>

# %%
os.path.exists(CrimeData)
# Out:
# True

# %%
CrimeTable = pd.read_csv(CrimeData)

# %%
pd.set_option('display.max_columns', 58)
pd.set_option('display.max_rows', 63)

# %%
CrimeTable
# Out:
#                                 Crimes  Alameda   Alpine   Amador   Butte   \
# 0                       Violent Crimes    9734.0     13.0    110.0  1024.0
# 1                             Homicide      96.0      0.0      1.0     7.0
# 2   Rape (Forcible Rape prior to 2014)     702.0      2.0      8.0   180.0
# 3                                 Rape     668.0      2.0      8.0   124.0
# 4                       Attempted Rape      34.0      0.0      0.0    56.0
# 5                              Robbery    4916.0      0.0      9.0   167.0
# 6                               Weapon       NaN      NaN      NaN     NaN
# 7                              Firearm    1707.0      0.0      0.0    38.0
# 8          Knife or Cutting Instrument     283.0      0.0      0.0    12.0
# 9                         Other Weapon     339.0      0.0      0.0    16.0
# 10                          Strong-Arm    2587.0      0.0      9.0   101.0
# ...

# %%
CleanCrimeTable = CrimeTable.drop([6, 11, 12, 13, 14, 15, 16, 17, 18, 20, 21, 22, 23, 24, 27, 30, 31, 32, 33, 34, 35, 36, 37, 38, 44, 48, 49, 50, 51, 52, 53, 54, 56, 55, 57, 60, 61, 62])

# %%
CleanCrimeTable.set_index("Crimes")
# Out:
#                                     Alameda   Alpine   Amador   Butte   \
# Crimes
# Violent Crimes                        9734.0     13.0    110.0  1024.0
# Homicide                                96.0      0.0      1.0     7.0
# Rape (Forcible Rape prior to 2014)     702.0      2.0      8.0   180.0
# Rape                                   668.0      2.0      8.0   124.0
# Attempted Rape                          34.0      0.0      0.0    56.0
# Robbery                               4916.0      0.0      9.0   167.0
# Firearm                               1707.0      0.0      0.0    38.0
# Knife or Cutting Instrument            283.0      0.0      0.0    12.0
# Other Weapon                           339.0      0.0      0.0    16.0
# Strong-Arm                            2587.0      0.0      9.0   101.0
# Aggravated Assault                    4020.0     11.0     92.0   670.0
# Property Crimes                      66731.0     32.0    670.0  5322.0
# ...

# %%
CleanCrimeTable.dtypes
# Out:
# Crimes              object
# Alameda            float64
# Alpine             float64
# Amador             float64
# Butte              float64
# Calaveras          float64
# Colusa             float64
# Contra Costa       float64
# Del Norte          float64
# El Dorado          float64
# Fresno             float64
# Glenn              float64
# Humboldt           float64
# Imperial           float64
# Inyo               float64
# Kern               float64
# Kings              float64
# Lake               float64
# Lassen             float64
# Los Angeles        float64
# Madera             float64
# Marin              float64
# Mariposa           float64
# Mendocino          float64
# Merced             float64
# Modoc              float64
# Mono               float64
# Monterey           float64
# Napa               float64
# Nevada             float64
# Orange             float64
# Placer             float64
# Plumas             float64
# Riverside          float64
# ...
